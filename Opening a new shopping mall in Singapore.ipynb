# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.colors as colors
# %matplotlib inline

# %% [markdown]
# ### 1. Import the CSV file

# %%
path = "/home/sissi/singapore_planning_area.csv"
df = pd.read_csv(path)
df
# Out:
#              X         Y  gid    Name  description               PLN_AREA_N  \
# 0   103.793357  1.328117    3   kml_3          NaN              BUKIT TIMAH
# 1   103.801664  1.376076    4   kml_4          NaN  CENTRAL WATER CATCHMENT
# 2   103.748492  1.387486    6   kml_6          NaN            CHOA CHU KANG
# 3   104.049107  1.387936   14  kml_14          NaN    NORTH-EASTERN ISLANDS
# 4   103.725202  1.362108   34  kml_34          NaN                   TENGAH
# 5   103.913796  1.406764   18  kml_18          NaN                  PUNGGOL
# 6   103.698202  1.312923   22  kml_22          NaN                 BOON LAY
# 7   103.892283  1.256292   38  kml_38          NaN              MARINA EAST
# 8   103.667422  1.306725   17  kml_17          NaN                  PIONEER
# 9   103.818933  1.457080   26  kml_26          NaN                SEMBAWANG
# 10  103.857281  1.444517   29  kml_29          NaN                  SIMPANG
# 11  103.773753  1.276400   24  kml_24          NaN               QUEENSTOWN
# 12  103.881743  1.420722   25  kml_25          NaN                  SELETAR
# 13  103.826155  1.229460   30  kml_30          NaN         SOUTHERN ISLANDS
# 14  103.884283  1.251698   39  kml_39          NaN             MARINA SOUTH
# 15  104.058846  1.324230   48  kml_48          NaN               CHANGI BAY
# 16  103.815114  1.307610   33  kml_33          NaN                  TANGLIN
# 17  103.727146  1.224018   52  kml_52          NaN          WESTERN ISLANDS
# 18  103.628906  1.276268   36  kml_36          NaN                     TUAS
# 19  103.856088  1.286587   37  kml_37          NaN            DOWNTOWN CORE
# 20  103.840985  1.308506   41  kml_41          NaN                   NEWTON
# 21  103.834065  1.304012   42  kml_42          NaN                  ORCHARD
# 22  103.868795  1.246133   47  kml_47          NaN             STRAITS VIEW
# 23  103.787925  1.443618   54  kml_54          NaN                WOODLANDS
# 24  103.821630  1.274457    1   kml_1          NaN              BUKIT MERAH
# 25  103.773045  1.366217    2   kml_2          NaN            BUKIT PANJANG
# 26  103.716885  1.435699   12  kml_12          NaN             LIM CHU KANG
# 27  104.001643  1.337079    5   kml_5          NaN                   CHANGI
# 28  103.760437  1.316511    7   kml_7          NaN                 CLEMENTI
# 29  103.888800  1.360946    8   kml_8          NaN                  HOUGANG
# 30  103.734817  1.317268    9   kml_9          NaN              JURONG EAST
# 31  103.704815  1.343955   10  kml_10          NaN              JURONG WEST
# 32  103.865107  1.312327   11  kml_11          NaN                  KALLANG
# 33  103.812815  1.427104   13  kml_13          NaN                   MANDAI
# 34  103.837228  1.326091   15  kml_15          NaN                   NOVENA
# 35  103.949546  1.379571   16  kml_16          NaN                PASIR RIS
# 36  103.842565  1.376729   19  kml_19          NaN               ANG MO KIO
# 37  103.944936  1.301108   20  kml_20          NaN                    BEDOK
# 38  103.837734  1.355160   21  kml_21          NaN                   BISHAN
# 39  103.752601  1.356029   23  kml_23          NaN              BUKIT BATOK
# 40  103.895550  1.388638   27  kml_27          NaN                 SENGKANG
# 41  103.867606  1.366010   28  kml_28          NaN                SERANGOON
# 42  103.755742  1.419650   31  kml_31          NaN             SUNGEI KADUT
# 43  103.968145  1.324290   32  kml_32          NaN                 TAMPINES
# 44  103.862479  1.336457   35  kml_35          NaN                TOA PAYOH
# 45  103.847505  1.295972   40  kml_40          NaN                   MUSEUM
# 46  103.843701  1.281626   43  kml_43          NaN                   OUTRAM
# 47  103.836371  1.297884   44  kml_44          NaN             RIVER VALLEY
# 48  103.854284  1.304995   45  kml_45          NaN                   ROCHOR
# 49  103.840498  1.290871   46  kml_46          NaN          SINGAPORE RIVER
# 50  103.913258  1.268724   49  kml_49          NaN            MARINE PARADE
# 51  103.889852  1.321163   50  kml_50          NaN                  GEYLANG
# 52  103.917381  1.360554   51  kml_51          NaN               PAYA LEBAR
# 53  103.694919  1.384956   53  kml_53          NaN  WESTERN WATER CATCHMENT
# 54  103.843395  1.419031   55  kml_55          NaN                   YISHUN
#
#    PLN_AREA_C CA_IND           REGION_N REGION_C           INC_CRC  \
# 0          BT      N     CENTRAL REGION       CR  6CCDADD1F85173E9
# 1          CC      N       NORTH REGION       NR  9F30125764C74984
# 2          CK      N        WEST REGION       WR  5224CD5C7960361F
# 3          NE      N  NORTH-EAST REGION      NER  E75708EADCFF04A6
# 4          TH      N        WEST REGION       WR  0D2FF9150EC36DFE
# 5          PG      N  NORTH-EAST REGION      NER  51833C3BEA49A0E9
# 6          BL      N        WEST REGION       WR  D67ECAA47DF4B485
# 7          ME      Y     CENTRAL REGION       CR  1B9566319261C802
# 8          PN      N        WEST REGION       WR  3202B87B465BF3BD
# 9          SB      N       NORTH REGION       NR  4794FB10E1985217
# 10         SM      N       NORTH REGION       NR  B2610C588D69AD76
# 11         QT      N     CENTRAL REGION       CR  1D9A77FAD9B4C935
# 12         SL      N  NORTH-EAST REGION      NER  56C392DFB629FEE9
# 13         SI      N     CENTRAL REGION       CR  4F0503C0A12D12AF
# 14         MS      Y     CENTRAL REGION       CR  B8C58231EDA3C8A6
# 15         CB      N        EAST REGION       ER  42AC44DA6E3279E0
# 16         TN      N     CENTRAL REGION       CR  CC1757F6434A3146
# 17         WI      N        WEST REGION       WR  FAF4016A22F192E5
# 18         TS      N        WEST REGION       WR  5708A19A15524F9D
# 19         DT      Y     CENTRAL REGION       CR  CE4B48C87C8B96CF
# 20         NT      Y     CENTRAL REGION       CR  45715157A7A3A806
# 21         OR      Y     CENTRAL REGION       CR  6F796784885688A9
# 22         SV      Y     CENTRAL REGION       CR  23358C7A78E76CE2
# 23         WD      N       NORTH REGION       NR  4DBDA89C0D15D5FD
# 24         BM      N     CENTRAL REGION       CR  5321BA51A092CCC2
# 25         BP      N        WEST REGION       WR  6C222E4C54F9F0F7
# 26         LK      N       NORTH REGION       NR  DF6880B736F7542D
# 27         CH      N        EAST REGION       ER  6F32A6036888B139
# 28         CL      N        WEST REGION       WR  1B547582113C390E
# 29         HG      N  NORTH-EAST REGION      NER  6B18B43959CDE4EB
# 30         JE      N        WEST REGION       WR  97CD8E4DB8DA2A0D
# 31         JW      N        WEST REGION       WR  15407CC4B888BDB5
# 32         KL      N     CENTRAL REGION       CR  C980FA4CF6B7E928
# 33         MD      N       NORTH REGION       NR  2B55BA3D015C2922
# 34         NV      N     CENTRAL REGION       CR  163B19CA54A679AF
# 35         PR      N        EAST REGION       ER  A68481F35761C70C
# 36         AM      N  NORTH-EAST REGION      NER  9745C6F57FDB836F
# 37         BD      N        EAST REGION       ER  E77152927962088E
# 38         BS      N     CENTRAL REGION       CR  F06B9400ED89EF69
# 39         BK      N        WEST REGION       WR  AE06442FEB6C5F2A
# 40         SE      N  NORTH-EAST REGION      NER  B977008C4E1A1CC8
# 41         SG      N  NORTH-EAST REGION      NER  99716E62F6EE17FF
# 42         SK      N       NORTH REGION       NR  04C6F9828DBC607D
# 43         TM      N        EAST REGION       ER  20DDDC25B5804F60
# 44         TP      N     CENTRAL REGION       CR  D70796621F573012
# 45         MU      Y     CENTRAL REGION       CR  0FF25CE84EE9F18C
# 46         OT      Y     CENTRAL REGION       CR  D346689682541537
# 47         RV      Y     CENTRAL REGION       CR  A145C7D45897566D
# 48         RC      Y     CENTRAL REGION       CR  83A4DC56F78F7A3E
# 49         SR      Y     CENTRAL REGION       CR  EA4AA9165CE146C1
# 50         MP      N     CENTRAL REGION       CR  C73536F2CD6206F6
# 51         GL      N     CENTRAL REGION       CR  31B24F4378BBAF9C
# 52         PL      N        EAST REGION       ER  CF70A103EED749D0
# 53         WC      N        WEST REGION       WR  53C9CA98365E8A5B
# 54         YS      N       NORTH REGION       NR  D20FD597C82D190A
#
#         FMEL_UPD_D
# 0   20191206144714
# 1   20191206144714
# 2   20191206144714
# 3   20191206144714
# 4   20191206144714
# 5   20191206144714
# 6   20191206144714
# 7   20191206144714
# 8   20191206144714
# 9   20191206144714
# 10  20191206144714
# 11  20191206144714
# 12  20191206144714
# 13  20191206144714
# 14  20191206144714
# 15  20191206144714
# 16  20191206144714
# 17  20191206144714
# 18  20191206144714
# 19  20191206144714
# 20  20191206144714
# 21  20191206144714
# 22  20191206144714
# 23  20191206144714
# 24  20191206144714
# 25  20191206144714
# 26  20191206144714
# 27  20191206144714
# 28  20191206144714
# 29  20191206144714
# 30  20191206144714
# 31  20191206144714
# 32  20191206144714
# 33  20191206144714
# 34  20191206144714
# 35  20191206144714
# 36  20191206144714
# 37  20191206144714
# 38  20191206144714
# 39  20191206144714
# 40  20191206144714
# 41  20191206144714
# 42  20191206144714
# 43  20191206144714
# 44  20191206144714
# 45  20191206144714
# 46  20191206144714
# 47  20191206144714
# 48  20191206144714
# 49  20191206144714
# 50  20191206144714
# 51  20191206144714
# 52  20191206144714
# 53  20191206144714
# 54  20191206144714

# %% [markdown]
# ### 2. Cleanse the data

# %%
sg_df = df.loc[:, ["X", "Y", "PLN_AREA_N","REGION_N"]]

sg_df.rename(columns ={"X":"Longitude", "Y":"Latitude", "PLN_AREA_N":"Neighborhood", "REGION_N":"Region"}, inplace=True)
sg_df['Neighborhood'] = sg_df['Neighborhood'].str.title()
sg_df['Region'] = sg_df['Region'].str.title()



sg_df
# Out:
#      Longitude  Latitude             Neighborhood             Region
# 0   103.793357  1.328117              Bukit Timah     Central Region
# 1   103.801664  1.376076  Central Water Catchment       North Region
# 2   103.748492  1.387486            Choa Chu Kang        West Region
# 3   104.049107  1.387936    North-Eastern Islands  North-East Region
# 4   103.725202  1.362108                   Tengah        West Region
# 5   103.913796  1.406764                  Punggol  North-East Region
# 6   103.698202  1.312923                 Boon Lay        West Region
# 7   103.892283  1.256292              Marina East     Central Region
# 8   103.667422  1.306725                  Pioneer        West Region
# 9   103.818933  1.457080                Sembawang       North Region
# 10  103.857281  1.444517                  Simpang       North Region
# 11  103.773753  1.276400               Queenstown     Central Region
# 12  103.881743  1.420722                  Seletar  North-East Region
# 13  103.826155  1.229460         Southern Islands     Central Region
# 14  103.884283  1.251698             Marina South     Central Region
# 15  104.058846  1.324230               Changi Bay        East Region
# 16  103.815114  1.307610                  Tanglin     Central Region
# 17  103.727146  1.224018          Western Islands        West Region
# 18  103.628906  1.276268                     Tuas        West Region
# 19  103.856088  1.286587            Downtown Core     Central Region
# 20  103.840985  1.308506                   Newton     Central Region
# 21  103.834065  1.304012                  Orchard     Central Region
# 22  103.868795  1.246133             Straits View     Central Region
# 23  103.787925  1.443618                Woodlands       North Region
# 24  103.821630  1.274457              Bukit Merah     Central Region
# 25  103.773045  1.366217            Bukit Panjang        West Region
# 26  103.716885  1.435699             Lim Chu Kang       North Region
# 27  104.001643  1.337079                   Changi        East Region
# 28  103.760437  1.316511                 Clementi        West Region
# 29  103.888800  1.360946                  Hougang  North-East Region
# 30  103.734817  1.317268              Jurong East        West Region
# 31  103.704815  1.343955              Jurong West        West Region
# 32  103.865107  1.312327                  Kallang     Central Region
# 33  103.812815  1.427104                   Mandai       North Region
# 34  103.837228  1.326091                   Novena     Central Region
# 35  103.949546  1.379571                Pasir Ris        East Region
# 36  103.842565  1.376729               Ang Mo Kio  North-East Region
# 37  103.944936  1.301108                    Bedok        East Region
# 38  103.837734  1.355160                   Bishan     Central Region
# 39  103.752601  1.356029              Bukit Batok        West Region
# 40  103.895550  1.388638                 Sengkang  North-East Region
# 41  103.867606  1.366010                Serangoon  North-East Region
# 42  103.755742  1.419650             Sungei Kadut       North Region
# 43  103.968145  1.324290                 Tampines        East Region
# 44  103.862479  1.336457                Toa Payoh     Central Region
# 45  103.847505  1.295972                   Museum     Central Region
# 46  103.843701  1.281626                   Outram     Central Region
# 47  103.836371  1.297884             River Valley     Central Region
# 48  103.854284  1.304995                   Rochor     Central Region
# 49  103.840498  1.290871          Singapore River     Central Region
# 50  103.913258  1.268724            Marine Parade     Central Region
# 51  103.889852  1.321163                  Geylang     Central Region
# 52  103.917381  1.360554               Paya Lebar        East Region
# 53  103.694919  1.384956  Western Water Catchment        West Region
# 54  103.843395  1.419031                   Yishun       North Region

# %% [markdown]
# ### 3. Create Singapore map using Folium

# %%
# get the coords of Singapore
from geopy.geocoders import Nominatim
address = "Singapore"

geolocator = Nominatim(user_agent="singapore_map")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Singapore 1.3408630000000001, 103.83039182212079.

# %%
import folium
sg_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, neighborhood in zip(sg_df["Latitude"], sg_df['Longitude'], sg_df['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        parse_html = False).add_to(sg_map)  
    
sg_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###  4. Use the Foursquare API to explore the neighborhoods

# %%
CLIENT_ID = 'MJQP45R4SJKHU0WEPOAGYVGMFA0LHN2E4PIEIAIVRVOYTSY5' # your Foursquare ID
CLIENT_SECRET = 'WJJ3H4413NZ4LM00LYUK32L24VV354GOERGQIFO3INCV0JB0' # your Foursquare Secret
VERSION = '20200811' # Foursquare API version
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MJQP45R4SJKHU0WEPOAGYVGMFA0LHN2E4PIEIAIVRVOYTSY5
# CLIENT_SECRET:WJJ3H4413NZ4LM00LYUK32L24VV354GOERGQIFO3INCV0JB0

# %% [markdown]
# #### Get the top 100 venues within the radius of 1500 meters.

# %%
LIMIT = 100
def getNearbyVenues(names, latitudes, longitudes, radius=1500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
sg_venues = getNearbyVenues(names = sg_df["Neighborhood"],
                            latitudes = sg_df["Latitude"],
                            longitudes = sg_df["Longitude"])
sg_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Bukit Timah               1.328117              103.793357
# 1  Bukit Timah               1.328117              103.793357
# 2  Bukit Timah               1.328117              103.793357
# 3  Bukit Timah               1.328117              103.793357
# 4  Bukit Timah               1.328117              103.793357
#
#                                    Venue  Venue Latitude  Venue Longitude  \
# 0  Plank Sourdough Pizza By Baker & Cook        1.323890       103.796797
# 1                       Brazil Churrasco        1.330798       103.795201
# 2                          MEAT n' CHILL        1.331425       103.794955
# 3                           Simply Bread        1.330535       103.795658
# 4                          Sunny Heights        1.334700       103.794795
#
#   Venue Category
# 0    Pizza Place
# 1   Churrascaria
# 2      BBQ Joint
# 3         Bakery
# 4        Dog Run

# %% [markdown]
# #### Check the count of venues for each neighborhood

# %%
sg_venues.groupby(['Neighborhood']).count()
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Ang Mo Kio                                 100                     100    100
# Bedok                                       22                      22     22
# Bishan                                     100                     100    100
# Boon Lay                                    28                      28     28
# Bukit Batok                                 78                      78     78
# Bukit Merah                                100                     100    100
# Bukit Panjang                               63                      63     63
# Bukit Timah                                 90                      90     90
# Central Water Catchment                      4                       4      4
# Changi                                       3                       3      3
# Changi Bay                                   3                       3      3
# Choa Chu Kang                               88                      88     88
# Clementi                                    76                      76     76
# Downtown Core                              100                     100    100
# Geylang                                    100                     100    100
# Hougang                                    100                     100    100
# Jurong East                                 28                      28     28
# Jurong West                                100                     100    100
# Kallang                                    100                     100    100
# Lim Chu Kang                                12                      12     12
# Mandai                                      14                      14     14
# Marina East                                  5                       5      5
# Marina South                                 5                       5      5
# Marine Parade                                5                       5      5
# Museum                                     100                     100    100
# Newton                                     100                     100    100
# North-Eastern Islands                        4                       4      4
# Novena                                     100                     100    100
# Orchard                                    100                     100    100
# Outram                                     100                     100    100
# Pasir Ris                                   57                      57     57
# Paya Lebar                                  12                      12     12
# Pioneer                                     10                      10     10
# Punggol                                     74                      74     74
# Queenstown                                  19                      19     19
# River Valley                               100                     100    100
# Rochor                                     100                     100    100
# Seletar                                      6                       6      6
# Sembawang                                   41                      41     41
# Sengkang                                    69                      69     69
# Serangoon                                   96                      96     96
# Simpang                                      4                       4      4
# Singapore River                            100                     100    100
# Southern Islands                             7                       7      7
# Straits View                                 7                       7      7
# Sungei Kadut                                19                      19     19
# Tampines                                   100                     100    100
# Tanglin                                    100                     100    100
# Tengah                                      23                      23     23
# Toa Payoh                                   60                      60     60
# Tuas                                         6                       6      6
# Western Islands                              6                       6      6
# Western Water Catchment                      4                       4      4
# Woodlands                                   85                      85     85
# Yishun                                     100                     100    100
#
#                          Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Ang Mo Kio                          100              100             100
# Bedok                                22               22              22
# Bishan                              100              100             100
# Boon Lay                             28               28              28
# Bukit Batok                          78               78              78
# Bukit Merah                         100              100             100
# Bukit Panjang                        63               63              63
# Bukit Timah                          90               90              90
# Central Water Catchment               4                4               4
# Changi                                3                3               3
# Changi Bay                            3                3               3
# Choa Chu Kang                        88               88              88
# Clementi                             76               76              76
# Downtown Core                       100              100             100
# Geylang                             100              100             100
# Hougang                             100              100             100
# Jurong East                          28               28              28
# Jurong West                         100              100             100
# Kallang                             100              100             100
# Lim Chu Kang                         12               12              12
# Mandai                               14               14              14
# Marina East                           5                5               5
# Marina South                          5                5               5
# Marine Parade                         5                5               5
# Museum                              100              100             100
# Newton                              100              100             100
# North-Eastern Islands                 4                4               4
# Novena                              100              100             100
# Orchard                             100              100             100
# Outram                              100              100             100
# Pasir Ris                            57               57              57
# Paya Lebar                           12               12              12
# Pioneer                              10               10              10
# Punggol                              74               74              74
# Queenstown                           19               19              19
# River Valley                        100              100             100
# Rochor                              100              100             100
# Seletar                               6                6               6
# Sembawang                            41               41              41
# Sengkang                             69               69              69
# Serangoon                            96               96              96
# Simpang                               4                4               4
# Singapore River                     100              100             100
# Southern Islands                      7                7               7
# Straits View                          7                7               7
# Sungei Kadut                         19               19              19
# Tampines                            100              100             100
# Tanglin                             100              100             100
# Tengah                               23               23              23
# Toa Payoh                            60               60              60
# Tuas                                  6                6               6
# Western Islands                       6                6               6
# Western Water Catchment               4                4               4
# Woodlands                            85               85              85
# Yishun                              100              100             100

# %%
print("There are {} unique categories".format(len(sg_venues["Venue Category"].unique())))
# Out:
# There are 303 unique categories

# %%
print(sg_venues['Venue Category'].value_counts())
# Out:
# Coffee Shop                  157
# Food Court                   148
# Chinese Restaurant           144
# Café                         107
# Japanese Restaurant           94
#                             ...
# Japanese Curry Restaurant      1
# Laundromat                     1
# Stables                        1
# Jazz Club                      1
# College Gym                    1
# Name: Venue Category, Length: 303, dtype: int64

# %% [markdown]
# #### Create a Data-frame with the 20 Most Frequently Occuring Venue_Category

# %%
# create a dataframe of top 10 categories
sg_top20 = sg_venues['Venue Category'].value_counts()[0:20].to_frame(name='frequency')
sg_top20 = sg_top20.reset_index()


sg_top20.rename(index=str, columns={"index": "Venue Category", "frequency": "Frequency"}, inplace=True)
sg_top20
# Out:
#           Venue Category  Frequency
# 0            Coffee Shop        157
# 1             Food Court        148
# 2     Chinese Restaurant        144
# 3                   Café        107
# 4    Japanese Restaurant         94
# 5                  Hotel         92
# 6       Asian Restaurant         80
# 7   Fast Food Restaurant         77
# 8            Supermarket         70
# 9                 Bakery         58
# 10         Shopping Mall         55
# 11                  Park         52
# 12     Indian Restaurant         49
# 13          Dessert Shop         41
# 14    Italian Restaurant         41
# 15    Seafood Restaurant         38
# 16           Bus Station         37
# 17            Restaurant         36
# 18          Noodle House         36
# 19       Thai Restaurant         36

# %%
import seaborn as sns
fig = plt.figure(figsize=(18,7))
s=sns.barplot(x="Venue Category", y="Frequency", data=sg_top10)
s.set_xticklabels(s.get_xticklabels(), rotation=30)
plt.title('20 Most Frequently Occuring Venues in Singapore', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("sg_top20", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8cea8ea81349> in <module>
#       1 import seaborn as sns
#       2 fig = plt.figure(figsize=(18,7))
# ----> 3 s=sns.barplot(x="Venue Category", y="Frequency", data=sg_top10)
#       4 s.set_xticklabels(s.get_xticklabels(), rotation=30)
#       5 plt.title('20 Most Frequently Occuring Venues in Singapore', fontsize=15)
#
# NameError: name 'sg_top10' is not defined

# %% [markdown]
# ### 5. Analyze Each Neighborhood

# %% [markdown]
# #### Add one hot encoding

# %%
sg_onehot = pd.get_dummies(sg_venues[['Venue Category']], prefix="", prefix_sep ="")

sg_onehot["Neighborhood"] = sg_venues['Neighborhood']

fixed_columns = [sg_onehot.columns[-1]] + list(sg_onehot.columns[:-1])
sg_onehot = sg_onehot[fixed_columns]

sg_onehot.head()

# %% [markdown]
# #### Group by neighborhoods

# %%
sg_grouped = sg_onehot.groupby(["Neighborhood"]).mean().reset_index()

print(sg_grouped.shape)
sg_grouped

# %% [markdown]
# #### New dataframe for all the existing shopping malls in Singapore

# %%
mall_sg = sg_grouped[['Neighborhood', 'Shopping Mall']]
mall_sg.head()

# %% [markdown]
# ### 6. Using K-Means clustering to cluster the neighborhoods

# %%
#import library
from sklearn.cluster import KMeans

#### Set into 3 clusters
kclusters = 3

sg_clustering = mall_sg.drop(["Neighborhood"], 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sg_clustering)

kmeans.labels_[0:10]

# %% [markdown]
# #### Create a new DataFrame that inlcudes the cluster and the top 10 malls for each neighborhood

# %%
sg_merged = mall_sg.copy()

sg_merged["Cluster Labels"] = kmeans.labels_

# %%
sg_merged.head()

# %% [markdown]
# #### merge sg_grouped with sg_df to add latitude/longitude for each neighborhood

# %%
sg_merged = sg_merged.join(sg_df.set_index("Neighborhood"), on="Neighborhood")

# %% [markdown]
# #### Sort the result by Cluster Labels

# %%
sg_merged.sort_values(["Cluster Labels"], inplace=True)
sg_merged

# %% [markdown]
# #### Visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location = [latitude, longitude], zoom_start = 11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i * x) ** 2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(sg_merged['Latitude'], sg_merged['Longitude'], sg_merged['Neighborhood'], sg_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius = 5,
        popup = label,
        color = rainbow[cluster - 1],
        fill = True,
        fill_color = rainbow[cluster - 1],
        fill_opacity = 0.7).add_to(map_clusters)
    
map_clusters

# %% [markdown]
# ### 7. Examine the clusters

# %% [markdown]
# ### First Cluster  (Cluster Labels=0)

# %%
sg_merged.loc[sg_merged['Cluster Labels'] == 0]

# %% [markdown]
# ### Second Cluster  (Cluster Labels=1)

# %%
sg_merged.loc[sg_merged['Cluster Labels'] == 1]

# %% [markdown]
# ### Third Cluster  (Cluster Labels=2)

# %%
sg_merged.loc[sg_merged['Cluster Labels'] == 2]

# %% [markdown]
# ### 8. Results and Discussion

# %% [markdown]
# As showed on the top 20 most common venue categories bar chart, we can find out that there are currently 55 shopping malls in Singapore and it's ranked the 11th most popular venue category.
#
# By observing the above clustering data, we could find the following analysis.
#
# - First cluster (Cluster label 0) has zero to very low numbers of shopping malls, as we can see, the neighborhoods in the first clusters are mostly in North/East/West Region. The density of population of most of these neighborhoods are not high.
# - Second cluster (Cluster label 1) has the highest rate of shopping malls. It's easy to identify most places are in central region. For example, Orchard is a well-known shopping center in Singapore. While Woodlands, even in North Region, but it's the regional center of the North Region and being located immediately across from Johor Bahru, Malaysia, Woodlands is highly accessible, connected as the border between two countries, which brings a certain amount of business including shopping malls.
# - Third cluster (Cluster label 2) shows a moderate amount of shopping malls, located mostly in West Region and Central Region.

# %% [markdown]
# ### Recommendations

# %% [markdown]
# I would strongly recommend the stakeholders avoid investing in the third cluster. Reasons are as follows:<br>
# 1. As we can see in the second cluster, there has been already a relatively high amount of shopping malls existed, which will be really competitive.
# 1. However, investing in the first cluster could be relatively risky, since most locations are in suburb area, which are less populated and are of industrial zones instead of residential areas.
# 1. In the third cluster, most neighborhoods are well-located in the central and west region, and currently there are a moderate amount of shopping malls, but not too competitive as the second cluster, which creates great potential for shopping mall investments.
